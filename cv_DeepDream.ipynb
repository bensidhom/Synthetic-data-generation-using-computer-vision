# %% [markdown]
# ## DeepDream

# %% [markdown]
# ### Implementing DeepDream in Keras

# %% [markdown]
# **Fetching the test image**

# %%
from tensorflow import keras
import matplotlib.pyplot as plt
import cv2
base_image_path = "/content/Capture d'écran 2023-12-04 033147.png"
#b= cv2.imread('/content/photoETU.jpg', cv2.IMREAD_COLOR)
plt.axis("off")
plt.imshow(keras.utils.load_img(base_image_path))
#plt.imshow(b)

# %% [markdown]
# **Instantiating a pretrained `InceptionV3` model**

# %%
from tensorflow.keras.applications import inception_v3
model = inception_v3.InceptionV3(weights="imagenet", include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step

# %% [markdown]
# **Configuring the contribution of each layer to the DeepDream loss**

# %%
layer_settings = {
    "mixed4": 1.0,
    "mixed5": 1.5,
    "mixed6": 2.0,
    "mixed7": 2.5,
}
outputs_dict = dict(
    [
        (layer.name, layer.output)
        for layer in [model.get_layer(name) for name in layer_settings.keys()]
    ]
)
feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)

# %% [markdown]
# **The DeepDream loss**

# %%
def compute_loss(input_image):
    features = feature_extractor(input_image)
    loss = tf.zeros(shape=())
    for name in features.keys():
        coeff = layer_settings[name]
        activation = features[name]
        loss += coeff * tf.reduce_mean(tf.square(activation[:, 2:-2, 2:-2, :]))
    return loss

# %% [markdown]
# **The DeepDream gradient ascent process**

# %%
import tensorflow as tf

@tf.function
def gradient_ascent_step(image, learning_rate):
    with tf.GradientTape() as tape:
        tape.watch(image)
        loss = compute_loss(image)
    grads = tape.gradient(loss, image)
    grads = tf.math.l2_normalize(grads)
    image += learning_rate * grads
    return loss, image


def gradient_ascent_loop(image, iterations, learning_rate, max_loss=None):
    for i in range(iterations):
        loss, image = gradient_ascent_step(image, learning_rate)
        if max_loss is not None and loss > max_loss:
            break
        print(f"... Loss value at step {i}: {loss:.2f}")
    return image

# %%
step = 20.
num_octave = 3
octave_scale = 1.4
iterations = 30
max_loss = 30.

# %% [markdown]
# **Image processing utilities**

# %%
import numpy as np

def preprocess_image(image_path):
    img = keras.utils.load_img(image_path)
    img = keras.utils.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = keras.applications.inception_v3.preprocess_input(img)
    return img

def deprocess_image(img):
    img = img.reshape((img.shape[1], img.shape[2], 3))
    img /= 2.0
    img += 0.5
    img *= 255.
    img = np.clip(img, 0, 255).astype("uint8")
    return img

# %% [markdown]
# **Running gradient ascent over multiple successive "octaves"**

# %%
original_img = preprocess_image(base_image_path)
original_shape = original_img.shape[1:3]

successive_shapes = [original_shape]
for i in range(1, num_octave):
    shape = tuple([int(dim / (octave_scale ** i)) for dim in original_shape])
    successive_shapes.append(shape)
successive_shapes = successive_shapes[::-1]

shrunk_original_img = tf.image.resize(original_img, successive_shapes[0])

img = tf.identity(original_img)
for i, shape in enumerate(successive_shapes):
    print(f"Processing octave {i} with shape {shape}")
    img = tf.image.resize(img, shape)
    img = gradient_ascent_loop(
        img, iterations=iterations, learning_rate=step, max_loss=max_loss
    )
    upscaled_shrunk_original_img = tf.image.resize(shrunk_original_img, shape)
    same_size_original = tf.image.resize(original_img, shape)
    lost_detail = same_size_original - upscaled_shrunk_original_img
    img += lost_detail
    shrunk_original_img = tf.image.resize(original_img, shape)

keras.utils.save_img("dream3.png", deprocess_image(img.numpy()))
# Out:
# Processing octave 0 with shape (263, 232)
# ... Loss value at step 0: 1.26
# ... Loss value at step 1: 1.79
# ... Loss value at step 2: 2.39
# ... Loss value at step 3: 2.94
# ... Loss value at step 4: 3.61
# ... Loss value at step 5: 4.20
# ... Loss value at step 6: 4.64
# ... Loss value at step 7: 5.03
# ... Loss value at step 8: 6.13
# ... Loss value at step 9: 6.53
# ... Loss value at step 10: 6.95
# ... Loss value at step 11: 7.59
# ... Loss value at step 12: 8.04
# ... Loss value at step 13: 8.87
# ... Loss value at step 14: 9.32
# ... Loss value at step 15: 10.56
# ... Loss value at step 16: 10.04
# ... Loss value at step 17: 11.02
# ... Loss value at step 18: 11.08
# ... Loss value at step 19: 12.57
# ... Loss value at step 20: 13.04
# ... Loss value at step 21: 14.79
# ... Loss value at step 22: 14.28
# ... Loss value at step 23: 15.98
# ... Loss value at step 24: 15.98
# ... Loss value at step 25: 17.72
# ... Loss value at step 26: 17.71
# ... Loss value at step 27: 18.40
# ... Loss value at step 28: 19.61
# ... Loss value at step 29: 22.27
# Processing octave 1 with shape (369, 325)
# ... Loss value at step 0: 1.18
# ... Loss value at step 1: 2.08
# ... Loss value at step 2: 2.92
# ... Loss value at step 3: 3.68
# ... Loss value at step 4: 4.39
# ... Loss value at step 5: 4.82
# ... Loss value at step 6: 5.72
# ... Loss value at step 7: 6.24
# ... Loss value at step 8: 7.40
# ... Loss value at step 9: 7.99
# ... Loss value at step 10: 8.59
# ... Loss value at step 11: 9.74
# ... Loss value at step 12: 10.40
# ... Loss value at step 13: 10.81
# ... Loss value at step 14: 11.46
# ... Loss value at step 15: 12.67
# ... Loss value at step 16: 13.06
# ... Loss value at step 17: 14.48
# ... Loss value at step 18: 14.79
# ... Loss value at step 19: 15.06
# ... Loss value at step 20: 16.41
# ... Loss value at step 21: 16.45
# ... Loss value at step 22: 16.65
# ... Loss value at step 23: 18.15
# ... Loss value at step 24: 18.63
# ... Loss value at step 25: 20.02
# ... Loss value at step 26: 20.89
# ... Loss value at step 27: 21.35
# ... Loss value at step 28: 21.81
# ... Loss value at step 29: 23.00
# Processing octave 2 with shape (517, 456)
# ... Loss value at step 0: 1.09
# ... Loss value at step 1: 1.94
# ... Loss value at step 2: 3.09
# ... Loss value at step 3: 5.22
# ... Loss value at step 4: 8.66
# ... Loss value at step 5: 13.03
# ... Loss value at step 6: 19.63
# ... Loss value at step 7: 28.65
